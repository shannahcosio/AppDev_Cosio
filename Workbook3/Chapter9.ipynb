# %% [markdown]
# Chapter 9

# %% [markdown]
# Exercise 1:
#
# Create a dictionary with the following keys and values showing a partial list of Real GDP growth in Annual percent change from IMF (Source: http://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD)
#
#     China 6.5
#     Japan 0.7
#     Philippines 6.7
#     United States 2.3

# %%
GDP_growth = {}
GDP_growth['China'] = 6.5
GDP_growth['Japan'] = 0.7
GDP_growth['Philippines'] = 6.7
GDP_growth['United States'] = 2.3

# %% [markdown]
# Exercise 2:
#
# Display all the keys and values from the dictionary you created above

# %%
#print(GDP_growth)
for key in GDP_growth:
    print(key, GDP_growth[key])
# Out:
# China 6.5
# Japan 0.7
# Philippines 6.7
# United States 2.3

# %% [markdown]
# Exercise 3:
#
# Write a program that asks the user to enter a line of text and then counts the number of each word that appeared in the line of text.
# Use the string function `split()` to make a list of words from a given string
# e.g.:
#
# ```python
# word_list = line.split()
# ```
#
# will return a list of words from the string `line` and store it in the variable `word_list`.
#
#
# (Adapted from [PES])

# %%
line = input("Enter a line of text: ")
word_list = line.split()
count_word = {}
for word in word_list :
    if word in count_word:
        count_word[word] += 1
    else:
        count_word[word] = 1
for key in count_word :
    print(key, "=" , count_word[key])
# Out:
# Enter a line of text: But I miss screaming and fighting and kissing in the rain And it's 2AM and I'm cursing your name You're so in love that you act insane And that's the way I loved you Breaking down and coming undone It's a roller coaster kind of rush And I never knew I could feel that much And that's the way I loved you
# But = 1
# I = 5
# miss = 1
# screaming = 1
# and = 4
# fighting = 1
# kissing = 1
# in = 2
# the = 3
# rain = 1
# And = 4
# it's = 1
# 2AM = 1
# I'm = 1
# cursing = 1
# your = 1
# name = 1
# You're = 1
# so = 1
# love = 1
# that = 2
# you = 3
# act = 1
# insane = 1
# that's = 2
# way = 2
# loved = 2
# Breaking = 1
# down = 1
# coming = 1
# undone = 1
# It's = 1
# a = 1
# roller = 1
# coaster = 1
# kind = 1
# of = 1
# rush = 1
# never = 1
# knew = 1
# could = 1
# feel = 1
# much = 1
