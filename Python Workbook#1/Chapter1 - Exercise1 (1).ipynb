# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Print('Hello world!')
#the "P" is in capital letter which is incorrect
# Out:
# Hello world!

# %%
print'Hello world!')
#no open parentheses
# Out:
#   File "<ipython-input-10-428a7af1cf15>", line 1
#     print'Hello world!')
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello world!)
#missing single quotation on the right side
# Out:
# Hello world

# %%
print('Hello world!'')
#there is two quotation on the right side which is incorrect
# Out:
# Hello world!

# %% [markdown]
# Exercise 2:

# %%
x = 43
x = x + 1
print(x)

#there is no error. x has a value of 43 which added to 1 having 44 as the output when x the printed
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x)

# the error occured because the x is capitalized in line 2
